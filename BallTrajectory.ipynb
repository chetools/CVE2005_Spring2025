422.8538828813,3292971.255097155,3739937.3024788015,4247571.552536903,4824108.704165374,5478901.179593945,6222570.8367302315,7067181.273927506,8026433.52225719,9115888.299750837,10353218.432956615,11758495.54052158,13354515.629299028,15167168.88470924,17225859.65398791,19563983.435170647,22219468.609395284,25235391.70434766,28660676.16948256,32550885.998350564,36969127.071950324,41987070.84443923,47686116.97714474,54158713.780794874,61509857.88580504,69858797.46785264,79340966.65797491,90110182.51665036,102341140.21054527,116232246.86798541,132008840.08314222,149926843.27860472,170276917.22259048,193389175.0455232,219638537.24165514,249450813.52303165,283309610.18393296,321764175.0250735,365438307.0957262,415040475.78504896,471375313.4116729,535356667.7410741,608022426.1649427,690551352.0162345,784282206.1337682,890735463.8610458,1011637979.7662071,1148951000.187311,1304901978.014407,1482020705.79886,1683180353.3309617,19116 ...

# %%
# F = rho * Cd * A * V^2 / 2
# Stokes Regime, Cd = 24/Re = 24*mu/(rho * V * D)

# F = rho * 24*mu/(rho * V * D) * pi * D^2 / 4 * V^2 /2
# F = 3 * mu* pi * V* D

D = 1e-7
mu = 1.8e-5
rho = 1.29

rho_particle = 2e3

weight = rho_particle * np.pi/6* D**3 * 9.81

# %%
# drop a sphere from an airplane
D = 1.8 #m
weight = 100. #kg
# F = rho * Cd * np.pi*(1.8) * V^2 / 2

# %%
Vguess = 100 #mph
Vguess = Vguess * 1610/3600

# %%
def net_force(V):
    Re = np.abs(rho * V * D / mu)
    A = (np.pi*D**2) / 4
    return np.copysign((rho * Cd(Re) * A * V**2) / 2, V) - weight

# %%
root(net_force, [40.])
# Out:
#  message: The solution converged.
#  success: True
#   status: 1
#      fun: [-1.421e-14]
#        x: [ 1.845e+01]
#   method: hybr
#     nfev: 12
#     fjac: [[-1.000e+00]]
#        r: [-1.237e+01]
#      qtf: [-3.573e-11]

# %%
D = 0.22 #m
A = np.pi*(D**2)/4
mu = 1.8e-5
rho = 1.29
m = 0.425 #kg
g= 9.81 #m/s2


def hit_ground(t, vec):
    x,y, vx, vy = vec
    return y

hit_ground.terminal = True
hit_ground.direction = -1

def rhs(t, vec):
    x,y, vx, vy = vec

    V = np.array([vx,vy])
    speed = np.linalg.norm(V)
    Re = rho * speed *D/mu
    Fd = -V/speed * Cd(Re) * A * rho * (speed**2)/2
    Fx, Fy = Fd
    dx = vx
    dy = vy
    dvx = Fx/ m
    dvy = -g + Fy/m

    return [dx, dy, dvx, dvy]

# %%
tend = 5.

Vi = 100 # mph
Vi = Vi * 1610. / 3600  #m/s
theta = 30 * np.pi/180 #rad
vxi = Vi * np.cos(theta)
vyi = Vi * np.sin(theta)


res = solve_ivp(rhs, (0,tend), [0,0, vxi, vyi], dense_output=True, events=hit_ground)

# %%
tplot = np.linspace(0,res.t_events[0][0], 100)
x,y,vx,vy = res.sol(tplot)

# %%
fig = make_subplots()
fig.add_scatter(x=x,y=y, mode='markers')
fig.update_layout(width=600,height=400,template='plotly_dark')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="f603e99f-e5b7-499d-8103-a94cec21df22" class="plotly-graph-div" style="height:400px; width:600px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("